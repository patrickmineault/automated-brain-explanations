# %%
# %load_ext autoreload
# %autoreload 2
import sys
import pandas as pd
import os
import matplotlib.pyplot as plt
import cortex
import seaborn as sns
from os.path import join
from collections import defaultdict
import numpy as np
from sklearn.preprocessing import StandardScaler
import joblib
import dvu
from copy import deepcopy
import sys
from numpy import ceil
sys.path.append('../notebooks')
from tqdm import tqdm
import neuro.config
from neuro.features.qa_questions import get_questions, get_merged_questions_v3_boostexamples
import neuro.viz
from PIL import Image
from neuro.flatmaps_helper import load_flatmaps, load_custom_rois, load_known_rois, ROI_EXPLANATIONS_S03, FED_DRIVING_EXPLANATIONS_S03, FED_DRIVING_EXPLANATIONS_S02


# main load
normalize_flatmaps = False
# gemv_flatmaps_dict_S02, gemv_flatmaps_dict_S03 = load_flatmaps(
    # normalize_flatmaps)
gemv_flatmaps_dict_S02, gemv_flatmaps_dict_S03, gemv_flatmaps_dict_S02_timecourse, gemv_flatmaps_dict_S03_timecourse = load_flatmaps(
    normalize_flatmaps, load_timecourse=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Select avg-response flatmaps

# %%
# select
avg_defaultdict = defaultdict(list)

for subject in ['S02', 'S03']:
    if subject == 'S03':
        gemv_flatmaps_dict = gemv_flatmaps_dict_S03
    elif subject == 'S02':
        gemv_flatmaps_dict = gemv_flatmaps_dict_S02
    common_keys = list(set(gemv_flatmaps_dict_S02.keys()).intersection(
        set(gemv_flatmaps_dict_S03.keys())))
    gemv_flatmaps_dict = {k: v for k,
                          v in gemv_flatmaps_dict.items() if k in common_keys}
    # gemv_flatmaps_dict = {k: v for k, v in gemv_flatmaps_dict.items(
    # ) if not k[0] in ROI_EXPLANATIONS_S03.values() and not k[0] in ['START', 'END']}

    ##################################################
    # rois_dict is a dictionary with keys as region names and np arrays of voxel masks as values

    # rois_dict_known = load_known_rois(subject)
    # rois_dict_comm = load_custom_rois(subject, suffix_setting='')
    rois_dict_fedorenko = load_custom_rois(
        subject, suffix_setting='_fedorenko')
    # rois_dict_spotlights = load_custom_rois(subject, suffix_setting='_spotlights')
    # | rois_dict_spotlights
    # rois_dict = rois_dict_comm | rois_dict_fedorenko  # | rois_dict_known
    # rois_dict = rois_dict_comm
    rois_dict = rois_dict_fedorenko

    ##################################################
    # compute means
    # avg_defaultdict = defaultdict(list)
    for roi_idx, roi in rois_dict.items():
        for explanation in gemv_flatmaps_dict.keys():
            avg_defaultdict[roi_idx + ' ' + subject].append(
                np.mean(gemv_flatmaps_dict[explanation][roi > 0]))
            # corrs_defaultdict[roi_idx].append(
            # np.corrcoef(roi, gemv_flatmaps_dict[explanation])[0, 1])

# %%
df = pd.DataFrame(avg_defaultdict, index=gemv_flatmaps_dict.keys())
# df = df.loc[common_keys]
df['AVG'] = df.mean(axis=1)

# remove 2nd val of index
df.index = [x[0] for x in df.index]

df = df.round(3).sort_values('AVG', ascending=False)
# display pandas formatting with redblue colormap centered at 0 rounded to 3 decimal places
vabs = max(abs(df.values.min()), abs(df.values.max()))
df.style.background_gradient(cmap='coolwarm', axis=None, vmax=vabs, vmin=-vabs).format("{:.3f}").set_caption(
    'Average GEM-V driving response averaged over ROI'
)
# Out:
# <style type="text/css">
# #T_770ca_row0_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_770ca_row0_col1, #T_770ca_row5_col10 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_770ca_row0_col2, #T_770ca_row7_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_770ca_row0_col3 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_770ca_row0_col4, #T_770ca_row15_col3 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_770ca_row0_col5, #T_770ca_row15_col2, #T_770ca_row19_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_770ca_row0_col6, #T_770ca_row6_col7, #T_770ca_row7_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_770ca_row0_col7, #T_770ca_row14_col3 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_770ca_row0_col8, #T_770ca_row3_col6, #T_770ca_row4_col3 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_770ca_row0_col9, #T_770ca_row4_col10, #T_770ca_row9_col7 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_770ca_row0_col10, #T_770ca_row2_col5 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_770ca_row1_col0, #T_770ca_row3_col1, #T_770ca_row5_col0, #T_770ca_row17_col2, #T_770ca_row22_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_770ca_row1_col1, #T_770ca_row4_col9, #T_770ca_row5_col1, #T_770ca_row11_col1, #T_770ca_row17_col5, #T_770ca_row19_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_770ca_row1_col2, #T_770ca_row3_col2, #T_770ca_row7_col0, #T_770ca_row10_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_770ca_row1_col3, #T_770ca_row9_col10, #T_770ca_row10_col10, #T_770ca_row13_col2, #T_770ca_row22_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_770ca_row1_col4, #T_770ca_row3_col4, #T_770ca_row11_col7, #T_770ca_row22_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_770ca_row1_col5, #T_770ca_row8_col9, #T_770ca_row12_col0, #T_770ca_row12_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_770ca_row1_col6 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_770ca_row1_col7, #T_770ca_row1_col8 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_770ca_row1_col9 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_770ca_row1_col10 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_770ca_row2_col0, #T_770ca_row2_col3, #T_770ca_row8_col2, #T_770ca_row8_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_770ca_row2_col1, #T_770ca_row16_col8 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_770ca_row2_col2 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_770ca_row2_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_770ca_row2_col6 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_770ca_row2_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_770ca_row2_col8 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_770ca_row2_col9 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_770ca_row2_col10, #T_770ca_row3_col5, #T_770ca_row10_col4 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_770ca_row3_col0, #T_770ca_row16_col2, #T_770ca_row16_col9 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_770ca_row3_col3, #T_770ca_row5_col6, #T_770ca_row11_col10, #T_770ca_row12_col10, #T_770ca_row18_col4, #T_770ca_row20_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_770ca_row3_col7, #T_770ca_row3_col8 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_770ca_row3_col9, #T_770ca_row12_col2 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_770ca_row3_col10, #T_770ca_row7_col6, #T_770ca_row9_col5, #T_770ca_row9_col8, #T_770ca_row10_col3 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_770ca_row4_col0 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_770ca_row4_col1, #T_770ca_row14_col4 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_770ca_row4_col2 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_770ca_row4_col4 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_770ca_row4_col5, #T_770ca_row4_col7, #T_770ca_row5_col3, #T_770ca_row10_col5, #T_770ca_row13_col10 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_770ca_row4_col6, #T_770ca_row14_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_770ca_row4_col8, #T_770ca_row16_col1, #T_770ca_row16_col5, #T_770ca_row18_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_770ca_row5_col2, #T_770ca_row17_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_770ca_row5_col4, #T_770ca_row9_col0, #T_770ca_row10_col7 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_770ca_row5_col5, #T_770ca_row6_col0, #T_770ca_row6_col2, #T_770ca_row11_col3, #T_770ca_row13_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_770ca_row5_col7 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_770ca_row5_col8 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_770ca_row5_col9, #T_770ca_row8_col8 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_770ca_row6_col1, #T_770ca_row7_col9 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_770ca_row6_col3, #T_770ca_row9_col6, #T_770ca_row10_col1, #T_770ca_row14_col0, #T_770ca_row14_col1, #T_770ca_row14_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_770ca_row6_col4, #T_770ca_row7_col10, #T_770ca_row10_col0, #T_770ca_row19_col3, #T_770ca_row20_col4 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_770ca_row6_col5, #T_770ca_row7_col8 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_770ca_row6_col6, #T_770ca_row6_col10, #T_770ca_row11_col4, #T_770ca_row13_col4, #T_770ca_row19_col2 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_770ca_row6_col8 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_770ca_row6_col9, #T_770ca_row20_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_770ca_row7_col1, #T_770ca_row9_col1, #T_770ca_row13_col7, #T_770ca_row16_col10 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_770ca_row7_col2, #T_770ca_row11_col6, #T_770ca_row13_col8, #T_770ca_row16_col4 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_770ca_row7_col4, #T_770ca_row10_col2, #T_770ca_row13_col0 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_770ca_row7_col5, #T_770ca_row8_col6 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_770ca_row8_col0, #T_770ca_row14_col6, #T_770ca_row17_col8 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_770ca_row8_col1, #T_770ca_row10_col8, #T_770ca_row20_col10 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_770ca_row8_col3, #T_770ca_row18_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_770ca_row8_col5 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_770ca_row8_col7 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_770ca_row8_col10, #T_770ca_row11_col2, #T_770ca_row13_col3 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_770ca_row9_col2, #T_770ca_row12_col8, #T_770ca_row14_col10, #T_770ca_row15_col10, #T_770ca_row16_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_770ca_row9_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_770ca_row9_col4, #T_770ca_row18_col8 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_770ca_row9_col9 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_770ca_row10_col9, #T_770ca_row18_col0, #T_770ca_row22_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_770ca_row11_col0, #T_770ca_row20_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_770ca_row11_col5 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_770ca_row11_col8, #T_770ca_row11_col9, #T_770ca_row19_col0, #T_770ca_row22_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_770ca_row12_col3, #T_770ca_row15_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_770ca_row12_col4 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_770ca_row12_col5, #T_770ca_row14_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_770ca_row12_col6, #T_770ca_row14_col8 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_770ca_row12_col7, #T_770ca_row17_col6 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_770ca_row12_col9, #T_770ca_r

# %%
plt.figure(figsize=(15, 10))
# add label to cbar
sns.heatmap(df, annot=True, fmt='.3f', cmap='coolwarm', center=0, vmin=-vabs, vmax=vabs,
            annot_kws={"size": 10}, cbar_kws={"label": "Average GEM-V driving response"}, linewidths=.5)
plt.tight_layout()
neuro.viz.savefig('gct_rois/fed_drive_full.pdf')
neuro.viz.savefig('gct_rois/fed_drive_full.png', dpi=300, bbox_inches='tight')

# %%
for subject in ['S03', 'S02']:
    if subject == 'S03':
        FED_DRIVING_EXPLANATIONS = FED_DRIVING_EXPLANATIONS_S03
    elif subject == 'S02':
        FED_DRIVING_EXPLANATIONS = FED_DRIVING_EXPLANATIONS_S02
    cols = [f'Lang-{i} {subject}' for i in range(5)]
    df_3 = df.loc[FED_DRIVING_EXPLANATIONS.values()][cols].rename(columns={
        k: k.replace(f' {subject}', '') for k in cols
    })
    plt.figure(figsize=(10, 6))
    # make fontsizes small
    sns.heatmap(df_3, annot=True, fmt='.3f', cmap='coolwarm', center=0, vmin=-vabs, vmax=vabs,
                cbar_kws={"label": "Average GEM-V driving response"}, linewidths=.5)
    dvu.outline_diagonal(df_3.values.shape, roffset=0.5,
                         coffset=0.5, color='black', lw=2)
    plt.tight_layout()
    plt.savefig(f'gct_rois/fed_drive_{subject}.pdf', bbox_inches='tight')

# %%
# sasc.viz._save_flatmap(
#     gemv_flatmaps_dict[('relationships between people', 'qa')], subject, fname_save=f'gemv_flatmaps/relationships_{subject}.png')

# %% [markdown]
# # Show flatmaps across subjects

# %%
S02_flatmaps_dir = join(RESULTS_DIR, 'processed',
                        'flatmaps_all', 'UTS02', 'roi')
S03_flatmaps_dir = join(RESULTS_DIR, 'processed',
                        'flatmaps_all', 'UTS03', 'roi')

# %%
# read a list of pngs and save them as a grid
for COMPARISONS in [
    ['Years', 'Time', 'Numbers', 'Measurements'],
    ['Relationships', 'Dialogue', 'Introspection'],
    ['Gruesome', 'Fear', 'Positive Emotional', 'Negative Emotional'],
    ['Clothing', 'Color'],
    ['Sexual', 'Secretive', 'Recognition', 'Professions']
]:

    pngs = defaultdict(list)
    for s in COMPARISONS:
        pngs['S02'] += [join(S02_flatmaps_dir, f)
                        for f in os.listdir(S02_flatmaps_dir) if f.endswith('.png') and s in f]
        pngs['S03'] += [join(S03_flatmaps_dir, f)
                        for f in os.listdir(S03_flatmaps_dir) if f.endswith('.png') and s in f]

    # plot as grid
    fig, axes = plt.subplots(
        2, len(COMPARISONS), figsize=(len(COMPARISONS) * 5, 6))
    for i, ax in enumerate(axes.flatten()):
        # ax.axis('off')
        # Remove all x-axis ticks and labels
        ax.xaxis.set_ticks([])
        ax.xaxis.set_ticklabels([])
        ax.xaxis.label.set_visible(False)

        # Remove all y-axis ticks and labels (but keep the y-axis label)
        ax.yaxis.set_ticks([])
        ax.yaxis.set_ticklabels([])

        for spine in ax.spines.values():
            spine.set_visible(False)

    for i in range(len(COMPARISONS)):
        axes[0, i].imshow(plt.imread(pngs['S02'][i]))
        axes[0, i].set_title(COMPARISONS[i])
        axes[1, i].imshow(plt.imread(pngs['S03'][i]))
        axes[0, 0].set_ylabel('S02')
        axes[1, 0].set_ylabel('S03')

    # add
    plt.savefig('__'.join(COMPARISONS) + '.png', bbox_inches='tight', dpi=300)
    plt.show()
