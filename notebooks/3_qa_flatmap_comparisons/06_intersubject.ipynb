# %%
# %load_ext autoreload
# %autoreload 2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from tqdm import tqdm
import pandas as pd
import sys
from typing import List
import numpy as np
from copy import deepcopy
import joblib
from pprint import pprint
from math import ceil
import cortex
from collections import defaultdict
from scipy.stats import norm
from statsmodels.stats.multitest import multipletests
import gct
from neuro.flatmaps_helper import load_flatmaps
import neuro.sasc.viz
from neuro import analyze_helper, config
from joblib import Memory

import nibabel as nib
neurosynth_compare = __import__('04_neurosynth_compare')
import neurosynth
from neuro.features.questions.gpt4 import QS_35_STABLE
import viz
config.setup_freesurfer()

subject = 'S02'
# subjects = [f'S0{i}' for i in range(1, 9) if not i == 6] # there's some problem with S06 surf2surf
subjects = ['S01', 'S02', 'S03']

# load flatmaps
d = defaultdict(list)
for subject in subjects:
    # if subject in ['S01', 'S02', 'S03']:
    # settings = ['individual_gpt4',
    # 'individual_gpt4_wordrate', 'shapley_35']
    # else:
    # settings = ['individual_gpt4_ndel=1_pc_new']
    settings = ['individual_gpt4_pc_new']
    flatmaps_qa_list = defaultdict(list)
    for setting in settings:
        flatmaps_qa_dict = joblib.load(
            join(config.PROCESSED_DIR, subject.replace('UT', ''), setting + '.pkl'))
        for q in flatmaps_qa_dict.keys():
            flatmaps_qa_list[q].append(flatmaps_qa_dict[q])
    flatmaps_qa_dict = {
        q: np.mean(flatmaps_qa_list[q], axis=0)
        for q in flatmaps_qa_list.keys()
    }
    # for k in sorted(flatmaps_qa_dict.keys()):
    for k in QS_35_STABLE:
        # print(k, flatmaps_qa_dict[k])
        # d[f'q_{subject}'].append(k)
        d[subject].append(flatmaps_qa_dict[k])

    # print(subject, len(flatmaps_qa_dict))
df = pd.DataFrame(d)
# df.set_index('q_S01', inplace=True)
df.index = QS_35_STABLE
df.index.name = 'question'
df = df[df.index.isin(QS_35_STABLE)]
assert df.shape[0] == 35
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# # save mni vols
# mni_arrs_list = []
# for q in tqdm(df.index):
#     mni_vols = []
#     for subject in subjects:
#         print(subject)
#         subj_vol = cortex.Volume(df.loc[q][subject], 'UT' + subject,
#                                  xfmname=f"UT{subject}_auto")
#         mni_vol = neurosynth.subj_vol_to_mni_surf(subj_vol, subject)
#         mni_vols.append(deepcopy(mni_vol))
#         mni_arrs = [mni_vol.data for mni_vol in mni_vols]
#     mni_arrs_list.append(deepcopy(mni_arrs))
# joblib.dump(mni_arrs_list, 'intersubject/mni_arrs_list.pkl')

# %%
memory = Memory(location="intersubject/mni_cache", verbose=0)


# load arrs for first 3 subjects
mni_arrs_list = joblib.load('intersubject/mni_arrs_list.pkl')
mni_arrs_list = [a[:3] for a in mni_arrs_list]
subjects = subjects[:3]


@memory.cache
def mni_arr_subj_arr_cachable(mni_arr, subject):
    mni_vol = cortex.Volume(mni_arr, "fsaverage", "atlas_2mm")
    subj_vol, subj_arr = neurosynth.mni_vol_to_subj_vol_surf(mni_vol, subject)
    return subj_arr


@memory.cache
def subj_arr_subj_arr_cachable(subj_arr, subject_input, subject_target):
    print('args', subj_arr.shape, subject_input, subject_target)
    subj_vol = cortex.Volume(subj_arr, subject='UT' + subject_input,
                             xfmname=f"UT{subject_input}_auto")
    return neurosynth.subj_vol_to_subj_surf(
        subj_vol, subject_input, subject_target)


# compute correlations
corrs_list = []
corrs_list_subj = []
corrs_list_subj_direct = []
for j, q in enumerate(df.index):
    # compute correlation between each one and mean of the others
    mni_arrs = np.array(mni_arrs_list[j])
    corrs_loo = []
    corrs_loo_subj = []
    corrs_loo_subj_direct = []
    for i, subj in enumerate(subjects):
        mni_arr = mni_arrs[i]
        subj_arr = df.loc[q][subj]
        other_mni_arrs = np.delete(mni_arrs, i, axis=0)
        mean_other_mni_arr = np.mean(other_mni_arrs, axis=0)

        # corr = np.corrcoef(mni_arr.flatten(),
        #                    mean_other_mni_arr.flatten())[0, 1]
        # print(f'mni corr between {i} and mean of others', corr)
        # corrs_loo.append(corr)

        mean_other_subj_arr = mni_arr_subj_arr_cachable(
            mean_other_mni_arr, subj)
        corr_subj = np.corrcoef(subj_arr.flatten(),
                                mean_other_subj_arr.flatten())[0, 1]
        print(f'subj corr between {i} and mean of others', corr_subj)
        corrs_loo_subj.append(corr_subj)

        other_subj_arrs = [
            subj_arr_subj_arr_cachable(
                df.loc[q][subj_input], subj_input, subject_target=subj)
            for subj_input in subjects if not subj_input == subj
        ]
        mean_other_subj_arr = np.mean(other_subj_arrs, axis=0)
        corr_subj_direct = np.corrcoef(subj_arr.flatten(),
                                       mean_other_subj_arr.flatten())[0, 1]
        print(
            f'subj dir corr between {i} and mean of others', corr_subj_direct)
        corrs_loo_subj_direct.append(corr_subj_direct)

    corrs_list.append(corrs_loo)
    corrs_list_subj.append(corrs_loo_subj)
    corrs_list_subj_direct.append(corrs_loo_subj_direct)
# Out:
# subj corr between 0 and mean of others 0.2965320656541517
# subj dir corr between 0 and mean of others 0.2887284278569169
# subj corr between 1 and mean of others 0.30257215122854936
# subj dir corr between 1 and mean of others 0.2919953071874567
# subj corr between 2 and mean of others 0.2988215536598398
# subj dir corr between 2 and mean of others 0.28943972666760037
# subj corr between 0 and mean of others 0.3019438571946109
# subj dir corr between 0 and mean of others 0.2930251697241289
# subj corr between 1 and mean of others 0.3065979959981462
# subj dir corr between 1 and mean of others 0.2955701820745028
# subj corr between 2 and mean of others 0.2133954687174337
# subj dir corr between 2 and mean of others 0.2062956843515375
# subj corr between 0 and mean of others 0.28303879004288074
# subj dir corr between 0 and mean of others 0.27520712847811396
# subj corr between 1 and mean of others 0.33839320511517573
# subj dir corr between 1 and mean of others 0.3250959986447265
# subj corr between 2 and mean of others 0.3218941666687906
# subj dir corr between 2 and mean of others 0.3108213389159348
# subj corr between 0 and mean of others 0.35633367420462564
# subj dir corr between 0 and mean of others 0.3464972329534599
# subj corr between 1 and mean of others 0.3585462944335873
# subj dir corr between 1 and mean of others 0.347311097946219
# subj corr between 2 and mean of others 0.31583889777269536
# subj dir corr between 2 and mean of others 0.3085673449218778
# subj corr between 0 and mean of others 0.3233119941233153
# subj dir corr between 0 and mean of others 0.31443481270111984
# subj corr between 1 and mean of others 0.2853671161102421
# subj dir corr between 1 and mean of others 0.2758341329069742
# subj corr between 2 and mean of others 0.2642364144667765
# subj dir corr between 2 and mean of others 0.25762768821902315
# subj corr between 0 and mean of others 0.3463126088665613
# subj dir corr between 0 and mean of others 0.33645351934457346
# subj corr between 1 and mean of others 0.3448787346382419
# subj dir corr between 1 and mean of others 0.3327164641714063
# subj corr between 2 and mean of others 0.31618212472314783
# subj dir corr between 2 and mean of others 0.30646639468280307
# subj corr between 0 and mean of others 0.33744044638852294
# subj dir corr between 0 and mean of others 0.3284633781620573
# subj corr between 1 and mean of others 0.37895330648543957
# subj dir corr between 1 and mean of others 0.36653196186138093
# subj corr between 2 and mean of others 0.33686074607158767
# subj dir corr between 2 and mean of others 0.32890028579950426
# subj corr between 0 and mean of others 0.30737317683338977
# subj dir corr between 0 and mean of others 0.2977111137092207
# subj corr between 1 and mean of others 0.2797024468999656
# subj dir corr between 1 and mean of others 0.2695683148510184
# subj corr between 2 and mean of others 0.17554173568530193
# subj dir corr between 2 and mean of others 0.16974159029815541
# subj corr between 0 and mean of others 0.1876773040341855
# subj dir corr between 0 and mean of others 0.17917877587860007
# subj corr between 1 and mean of others 0.17371065716453726
# subj dir corr between 1 and mean of others 0.16740359412882852
# subj corr between 2 and mean of others 0.10789233784557382
# subj dir corr between 2 and mean of others 0.10225049686618158
# subj corr between 0 and mean of others 0.34862674249341546
# subj dir corr between 0 and mean of others 0.339597823490475
# subj corr between 1 and mean of others 0.3386754779198386
# subj dir corr between 1 and mean of others 0.3268827830209196
# subj corr between 2 and mean of others 0.29283426753563824
# subj dir corr between 2 and mean of others 0.28482087665223554
# subj corr between 0 and mean of others 0.30727389753975265
# subj dir corr between 0 and mean of others 0.29834521264614566
# subj corr between 1 and mean of others 0.26329482778085184
# subj dir corr between 1 and mean of others 0.25382688138529375
# subj corr between 2 and mean of others 0.2621592598663895
# subj dir corr between 2 and mean of others 0.2537031207128223
# subj corr between 0 and mean of others 0.2917059213390253
# subj dir corr between 0 and mean of others 0.28456492415068096
# subj corr between 1 and mean of others 0.3156731150704957
# subj dir corr between 1 and mean of others 0.30568631898274307
# subj corr between 2 and mean of others 0.2707355262329377
# subj dir corr between 2 and mean of others 0.26226877702972634
# subj corr between 0 and mean of others 0.2824063541542368
# subj dir corr between 0 and mean of others 0.27129669768495157
# subj corr between 1 and mean of others 0.13691369169726136
# subj dir corr between 1 and mean of others 0.13064848090744213
# subj corr between 2 and mean of others 0.19803956816484633
# subj dir corr between 2 and mean of others 0.1922291167524106
# subj corr between 0 and mean of others 0.3363072878755879
# subj dir corr between 0 and mean of others 0.3274538883758974
# subj corr between 1 and mean of others 0.3428277322682235
# subj dir corr between 1 and mean of others 0.330510357680354
# subj corr between 2 and mean of others 0.3067398046774106
# subj dir corr between 2 and mean of others 0.2972257005687727
# subj corr between 0 and mean of others 0.18625685769622452
# subj dir corr between 0 and mean of others 0.17855317384661276
# subj corr between 1 and mean of others 0.2120056457910365
# subj dir corr between 1 and mean of others 0.2001011942708628
# subj corr between 2 and mean of others 0.18845155813458495
# subj dir corr between 2 and mean of others 0.17821194949527958
# subj corr between 0 and mean of others 0.3481918674570082
# subj dir corr between 0 and mean of others 0.3382098125044723
# subj corr between 1 and mean of others 0.3574092328646735
# subj dir corr between 1 and mean of others 0.34503996742494897
# subj corr between 2 and mean of others 0.3249543376667067
# subj dir corr between 2 and mean of others 0.31521869146924675
# subj corr between 0 and mean of others 0.19240325305994033
# subj dir corr between 0 and mean of others 0.18728469397180653
# subj corr between 1 and mean of others 0.25878765545166427
# subj dir corr between 1 and mean of others 0.2476971360620456
# subj corr between 2 and mean of others 0.2471924432514851
# subj dir corr between 2 and mean of others 0.23759181770558122
# subj corr between 0 and mean of others 0.2908461253222375
# subj dir corr between 0 and mean of others 0.28221096245593597
# subj corr between 1 and mean of others 0.30008592179573856
# subj dir corr between 1 and mean of others 0.2907803058122898
# subj corr between 2 and mean of others 0.25548217109934523
# subj dir corr between 2 and mean of others 0.24716677013370827
# subj corr between 0 and mean of others 0.30691784366467717
# subj dir corr between 0 and mean of others 0.298398458830776
# subj corr between 1 and mean of others 0.31155683589933053
# subj dir corr between 1 and mean of others 0.29998217487777856
# subj corr between 2 and mean of others 0.23812767918973385
# subj dir corr between 2 and mean of others 0.23151413796902065
# subj corr between 0 and mean of others 0.19313757076521756
# subj dir corr between 0 and mean of others 0.18860400864810958
# subj corr between 1 and mean of others 0.27566343143165667
# subj dir corr between 1 and mean of others 0.2658535262055994
# subj corr between 2 and mean of others 0.2531459536269568
# subj dir corr between 2 and mean of others 0.24492578114218913
# subj corr between 0 and mean of others 0.25452966086118534
# subj dir corr between 0 and mean of others 0.2477832093385298
# subj corr between 1 and mean of others 0.2517104870788682
# subj dir corr between 1 and mean of others 0.24342951305622298
# subj corr between 2 and mean of others 0.2234978326408686
# subj dir corr between 2 and mean of others 0.21534864422967662
# subj corr between 0 and mean of others 0.30934780733103096
# subj dir corr between 0 and mean of others 0.3020302766597617
# subj corr between 1 and mean of others 0.3600057936566062
# subj dir corr between 1 and mean of others 0.34869340081336125
# subj corr between 2 and mean of others 0.27678547969849626
# subj dir corr between 2 and mean of others 0.2683481259488658
# subj corr between 0 and mean of others 0.3783271715053188
# subj dir corr between 0 and mean of others 0.36881904252693454
# subj corr between 1 and mean of others 0.4089328671348379
# subj dir corr between 1 and mean of others 0.39577367801003616
# subj corr between 2 and mean of others 0.35854638726911886
# subj dir corr between 2 and mean of others 0.3513274473136648
# subj corr between 0 and mean of others 0.14813608032926306
# subj dir corr between 0 and mean of others 0.14395549908005595
# subj corr between 1 and mean of others 0.3543016900349306
# subj dir corr between 1 and mean of others 0.33500191048670086
# subj corr between 2 and mean of others 0.2809265307994704
# subj dir corr between 2 and mean of others 0.2696342485277029
# subj corr between 0 and mean of others 0.27380088975750877
# subj dir corr between 0 and mean of others 0.26420921031148187
# subj corr between 1 and mean of others 0.27781790697361736
# subj dir corr between 1 and mean of others 0.26578951872645906
# subj corr between 2 and mean of others 0.03883773950630197
# subj dir corr between 2 and mean of others 0.03837679116428994
# subj corr between 0 and mean of others 0.278919653935129
# subj dir corr between 0 and mean of others 0.27409437341734016
# subj corr between 1 and mean of others 0.3438755783393051
# subj dir corr between 1 and mean of others 0.3312158769529037
# subj corr between 2 and mean of others 0.296087131476169
# subj dir corr between 2 and mean of others 0.28646262403626266
# subj corr between 0 and mean of others 0.23672572729562277
# subj dir corr between 0 and mean of others 0.22776398155217284
# subj corr between 1 and mean of others 0.20405259349154195
# subj dir corr between 1 and mean of others 0.19773507729139703
# subj corr between 2 and mean of others 0.27237294681719154
# subj dir corr between 2 and mean of others 0.26036034765567584
# subj corr between 0 and mean of others 0.17214571980349067
# subj dir corr between 0 and mean of others 0.16474837662641664
# subj corr between 1 and mean of others 0.20225714753980398
# subj dir corr between 1 and mean of others 0.19130121589606008
# subj corr between 2 and mean of others 0.12073052889219629
# subj dir corr between 2 and mean of others 0.11603862247151708
# subj corr between 0 and mean of others 0.15726526250696024
# subj dir corr between 0 and mean of others 0.15299830223129898
# subj corr between 1 and mean of others 0.2677483691053743
# subj dir corr between 1 and mean of others 0.25747594278968244
# subj corr between 2 and mean of others 0.2888824612192882
# subj dir corr between 2 and mean of others 0.277742254038818
# subj corr between 0 and mean of others 0.3240771314069952
# subj dir corr between 0 and mean of others 0.3118706133614103
# subj corr between 1 and mean of others 0.2626300281201586
# subj dir corr between 1 and mean of others 0.2535166144863378
# subj corr between 2 and mean of others 0.24742312814339334
# subj dir corr between 2 and mean of others 0.23765704650846334
# subj corr between 0 and mean of others 0.1858707088672982
# subj dir corr between 0 and mean of others 0.1805433895153953
# subj corr between 1 and mean of others 0.2753960180772488
# subj dir corr between 1 and mean of others 0.26379505124684843
# subj corr between 2 and mean of others 0.20924369906041412
# subj dir corr between 2 and mean of others 0.20271156804369775
# subj corr between 0 and mean of others 0.22673960556860687
# subj dir corr between 0 and mean of others 0.21959915599358884
# subj corr between 1 and mean of others 0.31457437995838333
# subj dir corr between 1 and mean of others 0.30079226027853
# subj corr between 2 and mean of others 0.18633472269287707
# subj dir corr between 2 and mean of others 0.17964413678516972
# subj corr between 0 and mean of others 0.26323346920499147
# subj dir corr between 0 and mean of others 0.2529660366097334
# subj corr between 1 and mean of others 0.1350173947573149
# subj dir corr between 1 and mean of others 0.12882161817324453
# subj corr between 2 and mean of others 0.194787346431352
# subj dir corr between 2 and mean of others 0.18785180294685846
# subj corr between 0 and mean of others 0.3093513573563365
# subj dir corr between 0 and mean of others 0.2995606080672086
# subj corr between 1 and mean of others 0.2891526704278466
# subj dir corr between 1 and mean of others 0.27889282279077693
# subj corr between 2 and mean of others 0.22597528652083293
# subj dir corr between 2 and mean of others 0.21979264035668514
# subj corr between 0 and mean of others 0.25651951347852076
# subj dir corr between 0 and mean of others 0.25028434408568473
# subj corr between 1 and mean of others 0.362209090245881
# subj dir corr between 1 and mean of others 0.3462111163791771
# subj corr between 2 and mean of others 0.29710036824983393
# subj dir corr between 2 and mean of others 0.2872951006554774

# %%
# corrs_df = pd.DataFrame(np.array(corrs_list), columns=subjects, index=df.index)
# corrs_df = pd.DataFrame(np.array(corrs_list_subj_direct),
# columns=subjects, index=df.index)
corrs_df = pd.DataFrame(np.array(corrs_list_subj),
                        columns=subjects, index=df.index)
corrs_df.to_pickle('corrs_df/intersubject.pkl')

# flatten with column name as value for a new column
corrs_df = corrs_df.melt(
    ignore_index=False, var_name='subject', value_name='corrs').reset_index()
corrs_df.rename(columns={'question': 'questions'}, inplace=True)

plt.figure(figsize=(11, 6), dpi=300)
neurosynth_compare.plot_corrs_df(
    corrs_df,
    out_dir='intersubject',
    plot_val=f'corrs',
    xlab=f'Inter-subject correlation\n(Each subject vs. the average of the other two)',
)
plt.show()

# %%
corrs_df = pd.DataFrame(np.array(corrs_list_subj),
                        columns=subjects, index=df.index)

# %% [markdown]
# ### statistical tests

# %%
# baseline_distrs = []
# for i, subject in enumerate(tqdm(['UTS01', 'UTS02', 'UTS03'])):
#     flatmaps_qa_list = [arr[i].flatten() for arr in mni_arrs_list]
#     flatmaps_null = np.array(joblib.load(
#         join(PROCESSED_DIR,
#              #  subject.replace('UT', ''), 'resp_chunks_1trs.pkl')))
#              subject.replace('UT', ''), 'resp_chunks_1trs_MNI.pkl')))
#     # flatmaps_null = [arr.flatten() for arr in flatmaps_null]
#     flatmaps_null = flatmaps_null.reshape(flatmaps_null.shape[0], -1)

#     _, baseline_distr = viz.compute_pvals(
#         flatmaps_qa_list,
#         frac_voxels_to_keep=1,
#         corrs_gt_arr=corrs_df[f'corrs'].values,
#         flatmaps_null=flatmaps_null,
#     )

#     baseline_distrs.append(baseline_distr)
# joblib.dump(baseline_distrs, 'baseline_distrs.pkl')

# %%
baseline_distrs = joblib.load('baseline_distrs.pkl')

# %%
vals_baseline = np.array(baseline_distrs).mean(axis=0)
vals_alt = corrs_df[f'corrs'].values

n = len(vals_alt)
print(np.mean(vals_alt))

# permutation test on mean
n_samples = 1000
means_baseline = [
    np.mean(np.random.choice(vals_baseline.flatten(), size=n, replace=False))
    for i in range(n_samples)
]
print('mean test p', np.mean(np.array(means_baseline) >= np.mean(vals_alt)))

# permutation test on individuals
pvals = []
for i in range(len(vals_baseline)):
    pvals.append(np.mean(vals_baseline[i] >= vals_alt[i]))
pvals = multipletests(
    pvals, method='fdr_bh', alpha=0.05)[1]
print('individual pvals (err corrected)',
      pvals, 'num sig', np.sum(pvals < 0.05))

# %% [markdown]
# ### Export mean mni arrs

# %%
mni_arr_mean_dict = {
    k: np.mean(v, axis=0) for k, v in zip(df.index, mni_arrs_list)
}
joblib.dump(mni_arr_mean_dict,
            'intersubject/mni_arr_mean_dict.pkl')

# %%
len(mni_arr_mean_dict)

# %%
list(mni_arr_mean_dict.values())[0].shape

# %%
d = joblib.load('intersubject/mni_arr_mean_dict.pkl')
# d['Does the sentence describe a personal reflection or thought?'].dtype

# %%
# !rclone copy /home/chansingh/fmri/notebooks_gt_flatmaps/intersubject/mni_arr_mean_dict.pkl box:DeepTune/QA/flatmaps_mni --progress
